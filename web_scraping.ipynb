# %% [markdown]
# <a href="https://colab.research.google.com/github/Sai-Krishna-t/Python-Google-Collab/blob/main/web_scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Web Scraping wih Beautiful soup
#
# Web scraping in Python is the process of automatically extracting data from websites. The most common tools are requests (to fetch web pages) and BeautifulSoup (to parse HTML).

# %%
pip install bs4

# %%
from bs4 import BeautifulSoup
html = """
<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8">
  <title>First HTML Page</title>
</head>
<body>
  <div id="first">
    <h3 data-example="yes">hi</h3>
    <p>more text.</p>
  </div>
  <ol>
    <li class="special super-special">This list item is special.</li>
    <li class="special something-special">This list item is also special.</li>
    <li>This list item is not special.</li>
  </ol>
  <div data-example="yes">bye</div>
</body>
</html>
"""

soup = BeautifulSoup(html, "html.parser")
print(soup.prettify(), type(soup))
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    First HTML Page
#   </title>
#  </head>
#  <body>
#   <div id="first">
#    <h3 data-example="yes">
#     hi
#    </h3>
#    <p>
#     more text.
#    </p>
#   </div>
#   <ol>
#    <li class="special super-special">
#     This list item is special.
#    </li>
#    <li class="special something-special">
#     This list item is also special.
#    </li>
#    <li>
#     This list item is not special.
#    </li>
#   </ol>
#   <div data-example="yes">
#    bye
#   </div>
#  </body>
# </html>
#  <class 'bs4.BeautifulSoup'>

# %%
print(soup.body)
# Out:
# <body>
# <div id="first">
# <h3 data-example="yes">hi</h3>
# <p>more text.</p>
# </div>
# <ol>
# <li class="special super-special">This list item is special.</li>
# <li class="special something-special">This list item is also special.</li>
# <li>This list item is not special.</li>
# </ol>
# <div data-example="yes">bye</div>
# </body>

# %%
print(soup.body.div)
# Out:
# <div id="first">
# <h3 data-example="yes">hi</h3>
# <p>more text.</p>
# </div>

# %%
print(soup.find("div"), type(soup.find("div")))
# Out:
# <div id="first">
# <h3 data-example="yes">hi</h3>
# <p>more text.</p>
# </div> <class 'bs4.element.Tag'>

# %%
soup.find_all("div") # list of tags
# Out:
# [<div id="first">
#  <h3 data-example="yes">hi</h3>
#  <p>more text.</p>
#  </div>,
#  <div data-example="yes">bye</div>]

# %%
soup.find("ol")
# Out:
# <ol>
# <li class="special super-special">This list item is special.</li>
# <li class="special something-special">This list item is also special.</li>
# <li>This list item is not special.</li>
# </ol>

# %%
soup.find_all('li')
# Out:
# [<li class="special super-special">This list item is special.</li>,
#  <li class="special something-special">This list item is also special.</li>,
#  <li>This list item is not special.</li>]

# %%
# using attributes
soup.find(id="first")
# Out:
# <div id="first">
# <h3 data-example="yes">hi</h3>
# <p>more text.</p>
# </div>

# %%
soup.find(class = "special") #class is a keyword in python
# Out:
#   File "/tmp/ipykernel_2350/1981423654.py", line 1
#     soup.find(class = "special") #class is a keyword in python
#               ^
# SyntaxError: invalid syntax

# %%
soup.find(class_="special")
# Out:
# <li class="special super-special">This list item is special.</li>

# %%
soup.find_all(class_="special")
# Out:
# [<li class="special super-special">This list item is special.</li>,
#  <li class="special something-special">This list item is also special.</li>]

# %% [markdown]
# ## Using CSS Selectors

# %%
# select IDs
soup = BeautifulSoup(html, "html.parser")
d = soup.select("#first")
print(d)
print('\n')
print(d[0])
# Out:
# [<div id="first">
# <h3 data-example="yes">hi</h3>
# <p>more text.</p>
# </div>]
#
#
# <div id="first">
# <h3 data-example="yes">hi</h3>
# <p>more text.</p>
# </div>

# %%
# using general attributes
d = soup.select("[data-example]")
d
# Out:
# [<h3 data-example="yes">hi</h3>, <div data-example="yes">bye</div>]

# %%
# select class
d = soup.select(".special")
d
# Out:
# [<li class="special super-special">This list item is special.</li>,
#  <li class="special something-special">This list item is also special.</li>]

# %% [markdown]
# ## Accessing data with BS4

# %%
soup = BeautifulSoup(html, "html.parser")
print(soup)
d = soup.select(".special")
d[0]
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>First HTML Page</title>
# </head>
# <body>
# <div id="first">
# <h3 data-example="yes">hi</h3>
# <p>more text.</p>
# </div>
# <ol>
# <li class="special super-special">This list item is special.</li>
# <li class="special something-special">This list item is also special.</li>
# <li>This list item is not special.</li>
# </ol>
# <div data-example="yes">bye</div>
# </body>
# </html>
# <li class="special super-special">This list item is special.</li>

# %%
for l in d:
    print(l.get_text())
# Out:
# This list item is special.
# This list item is also special.

# %%
for l in d:
    print(l.name)
    print(l.attrs)
    print(l.attrs['class'])
# Out:
# li
# {'class': ['special', 'super-special']}
# ['special', 'super-special']
# li
# {'class': ['special', 'something-special']}
# ['special', 'something-special']

# %%
soup.find('h3')
# Out:
# <h3 data-example="yes">hi</h3>

# %%
soup.find('div')
# Out:
# <div id="first">
# <h3 data-example="yes">hi</h3>
# <p>more text.</p>
# </div>

# %%
soup.find('div')["id"]
# Out:
# 'first'

# %% [markdown]
# ## navigating using BS4, finding parent, parent sibling etc

# %%
soup = BeautifulSoup(html, "html.parser")
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>First HTML Page</title>
# </head>
# <body>
# <div id="first">
# <h3 data-example="yes">hi</h3>
# <p>more text.</p>
# </div>
# <ol>
# <li class="special super-special">This list item is special.</li>
# <li class="special something-special">This list item is also special.</li>
# <li>This list item is not special.</li>
# </ol>
# <div data-example="yes">bye</div>
# </body>
# </html>

# %%
soup.body
# Out:
# ['\n',
#  <div id="first">
#  <h3 data-example="yes">hi</h3>
#  <p>more text.</p>
#  </div>,
#  '\n',
#  <ol>
#  <li class="special super-special">This list item is special.</li>
#  <li class="special something-special">This list item is also special.</li>
#  <li>This list item is not special.</li>
#  </ol>,
#  '\n',
#  <div data-example="yes">bye</div>,
#  '\n']

# %%
soup.body.contents
# Out:
# ['\n',
#  <div id="first">
#  <h3 data-example="yes">hi</h3>
#  <p>more text.</p>
#  </div>,
#  '\n',
#  <ol>
#  <li class="special super-special">This list item is special.</li>
#  <li class="special something-special">This list item is also special.</li>
#  <li>This list item is not special.</li>
#  </ol>,
#  '\n',
#  <div data-example="yes">bye</div>,
#  '\n']

# %%
soup.body.contents[1].parent
# Out:
# <body>
# <div id="first">
# <h3 data-example="yes">hi</h3>
# <p>more text.</p>
# </div>
# <ol>
# <li class="special super-special">This list item is special.</li>
# <li class="special something-special">This list item is also special.</li>
# <li>This list item is not special.</li>
# </ol>
# <div data-example="yes">bye</div>
# </body>

# %%
soup.body.contents[1].next_sibling
# Out:
# '\n'

# %%
soup.body.contents[1].next_sibling.next_sibling
# Out:
# <ol>
# <li class="special super-special">This list item is special.</li>
# <li class="special something-special">This list item is also special.</li>
# <li>This list item is not special.</li>
# </ol>

# %%
data = soup.find(class_="special")
data.contents
# Out:
# ['This list item is special.']

# %%
data.next_sibling
# Out:
# '\n'

# %%
## Via searching
soup = BeautifulSoup(html, "html.parser")
data = soup.find(id='first').find_next_sibling()
data
# Out:
# <ol>
# <li class="special super-special">This list item is special.</li>
# <li class="special something-special">This list item is also special.</li>
# <li>This list item is not special.</li>
# </ol>

# %%
soup = BeautifulSoup(html, "html.parser")
data = soup.select('[data-example]')
data
# Out:
# [<h3 data-example="yes">hi</h3>, <div data-example="yes">bye</div>]

# %%
data[1].find_previous_sibling()
# Out:
# <ol>
# <li class="special super-special">This list item is special.</li>
# <li class="special something-special">This list item is also special.</li>
# <li>This list item is not special.</li>
# </ol>
